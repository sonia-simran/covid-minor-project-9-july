# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('coviddelhinew.csv',parse_dates=[0], dayfirst=True)
df.head()
# Out:
#   Sno        Date     Time State/UnionTerritory  Cured  Deaths  Confirmed
# 0   1  01-06-2020  8:00 AM                Delhi   8478     473      19844
# 1   2  01-06-2020  8:00 AM              Haryana   1048      20       2091
# 2   3  01-06-2020  8:00 AM        Uttar Pradesh   4709     213       7823
# 3   4  02-06-2020  8:00 AM                Delhi   8746     523      20834
# 4   5  02-06-2020  8:00 AM              Haryana   1055      21       2356

# %%
df.tail(5)
# Out:
#    Sno        Date     Time State/UnionTerritory  Cured  Deaths  Confirmed
# 85  86  29-06-2020  8:00 AM              Haryana   8917     223      13829
# 86  87  29-06-2020  8:00 AM        Uttar Pradesh  14808     660      22147
# 87  88  30-06-2020  8:00 AM                Delhi  56235    2680      85161
# 88  89  30-06-2020  8:00 AM              Haryana   9502     232      14210
# 89  90  30-06-2020  8:00 AM        Uttar Pradesh  15506     672      22828

# %%
df[:-5]
# Out:
#    Sno        Date     Time State/UnionTerritory  Cured  Deaths  Confirmed
# 0    1  01-06-2020  8:00 AM                Delhi   8478     473      19844
# 1    2  01-06-2020  8:00 AM              Haryana   1048      20       2091
# 2    3  01-06-2020  8:00 AM        Uttar Pradesh   4709     213       7823
# 3    4  02-06-2020  8:00 AM                Delhi   8746     523      20834
# 4    5  02-06-2020  8:00 AM              Haryana   1055      21       2356
# ..  ..         ...      ...                  ...    ...     ...        ...
# 80  81  27-06-2020  8:00 AM        Uttar Pradesh  13583     630      20943
# 81  82  28-06-2020  8:00 AM                Delhi  49301    2558      80188
# 82  83  28-06-2020  8:00 AM              Haryana   8472     218      13427
# 83  84  28-06-2020  8:00 AM        Uttar Pradesh  14215     649      21549
# 84  85  29-06-2020  8:00 AM                Delhi  52607    2623      83077
#
# [85 rows x 7 columns]

# %%
df_confirm = pd.DataFrame(df, columns= ["Date","Confirmed","State/UnionTerritory"])
df_confirm

#df_confirm[:-5]
# Out:
#           Date  Confirmed State/UnionTerritory
# 0   01-06-2020      19844                Delhi
# 1   01-06-2020       2091              Haryana
# 2   01-06-2020       7823        Uttar Pradesh
# 3   02-06-2020      20834                Delhi
# 4   02-06-2020       2356              Haryana
# ..         ...        ...                  ...
# 85  29-06-2020      13829              Haryana
# 86  29-06-2020      22147        Uttar Pradesh
# 87  30-06-2020      85161                Delhi
# 88  30-06-2020      14210              Haryana
# 89  30-06-2020      22828        Uttar Pradesh
#
# [90 rows x 3 columns]

# %%
df_cure = pd.DataFrame(df, columns= ["Date","Cured","State/UnionTerritory"])
df_cure
# Out:
#           Date  Cured State/UnionTerritory
# 0   01-06-2020   8478                Delhi
# 1   01-06-2020   1048              Haryana
# 2   01-06-2020   4709        Uttar Pradesh
# 3   02-06-2020   8746                Delhi
# 4   02-06-2020   1055              Haryana
# ..         ...    ...                  ...
# 85  29-06-2020   8917              Haryana
# 86  29-06-2020  14808        Uttar Pradesh
# 87  30-06-2020  56235                Delhi
# 88  30-06-2020   9502              Haryana
# 89  30-06-2020  15506        Uttar Pradesh
#
# [90 rows x 3 columns]

# %%
df_death = pd.DataFrame(df, columns= ["Date","Deaths","State/UnionTerritory"])
df_death

#df.drop(df.tail(3).index, inplace = True)
#df
# Out:
#           Date  Deaths State/UnionTerritory
# 0   01-06-2020     473                Delhi
# 1   01-06-2020      20              Haryana
# 2   01-06-2020     213        Uttar Pradesh
# 3   02-06-2020     523                Delhi
# 4   02-06-2020      21              Haryana
# ..         ...     ...                  ...
# 85  29-06-2020     223              Haryana
# 86  29-06-2020     660        Uttar Pradesh
# 87  30-06-2020    2680                Delhi
# 88  30-06-2020     232              Haryana
# 89  30-06-2020     672        Uttar Pradesh
#
# [90 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Sno                   90 non-null     object
#  1   Date                  90 non-null     object
#  2   Time                  90 non-null     object
#  3   State/UnionTerritory  90 non-null     object
#  4   Cured                 90 non-null     int64
#  5   Deaths                90 non-null     int64
#  6   Confirmed             90 non-null     int64
# dtypes: int64(3), object(4)
# memory usage: 5.0+ KB

# %%
sb.scatterplot(x='Deaths',y='Confirmed', data=df)
#

# %%
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

 #Handle date time conversions between pandas and matplotlib

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
junepredict = pd.read_csv("coviddelhinew.csv",
                          parse_dates=['Date'],
                          index_col= ['Date'])
                
juneend = junepredict['2020-06-01':'2020-06-30']

juneend.head()
fig, ax = plt.subplots(figsize=(8,5))

ax.bar(juneend.index.values,juneend['Confirmed'],color = 'purple')

 # Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Confirmed",
       title =" June Month Prediction of Confirmed Cases in Delhi,Haryana,Uttarpardesh")
                 
plt.show()
# Define the date format
date_form = DateFormatter("%m-%d")
ax.xaxis.set_major_formatter(date_form)

# %%
junepredict = pd.read_csv("coviddelhinew.csv",
                          parse_dates=['Date'],
                          index_col= ['Date'])
                 
juneend = junepredict['2020-06-01':'2020-06-30']

juneend.head()
 
fig, ax = plt.subplots(figsize=(8,5))

# Add x-axis and y-axis
ax.bar(juneend.index.values,juneend['Cured'],color = 'green')

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Cured",
       title = "June Month Prediction of Cured Cases in Delhi,Haryana,Uttarpardesh")
                 
plt.show()
# Define the date format
date_form = DateFormatter("%m-%d")
ax.xaxis.set_major_formatter(date_form)

# %%
junepredict = pd.read_csv("coviddelhinew.csv",
                          parse_dates=['Date'],
                          index_col= ['Date'])
                
juneend = junepredict['2020-06-01':'2020-06-30']
juneend.head()
   
fig, ax = plt.subplots(figsize=(12,5))

# Add x-axis and y-axis
ax.bar(juneend.index.values,juneend['Deaths'],color = 'red')
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Deaths",
       title ="June Month Prediction of Death cases in Delhi,Haryana,Uttarpardesh")
                 
plt.show()
                 
# Define the date format
date_form = DateFormatter("%m-%d")
ax.xaxis.set_major_formatter(date_form)

# %%
junepredict = pd.read_csv("coviddelhinew.csv",
                          parse_dates=['Date'],
                          index_col= ['Date'])
                 
juneend = junepredict['2020-06-01':'2020-06-30']
juneend.head()
                 
fig, ax = plt.subplots(figsize=(10,5))

ax.bar(juneend.index.values,juneend['State/UnionTerritory'],color = 'cyan')
    
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel= "State/UnionTerritory",
       title = "June Month Prediction of Cured Cases in Delhi,Haryana,Uttarpardesh")                 
plt.show()
  
# Define the date format
date_form = DateFormatter("%m-%d")
ax.xaxis.set_major_formatter(date_form)
